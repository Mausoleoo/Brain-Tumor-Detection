# %%
import tensorflow as tf
import os
from matplotlib.image import imread #Open image as an array
import numpy as np

# %% [markdown]
# ## Visualize Images

# %%
from PIL import Image

# %%
directory = 'Datasets/'
dirYES = os.listdir(directory + 'yes')
dirNO = os.listdir(directory + 'no')

# %% [markdown]
# #### Example image with tumor

# %%
Image.open(directory + 'yes/' + dirYES[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=287x348 at 0x1C967E85B80>

# %% [markdown]
# #### Example image without tumor

# %%
Image.open(directory + 'no/' + dirNO[6])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=441x442 at 0x1C961326070>

# %% [markdown]
# ## Resize images

# %% [markdown]
# #### Resize images with tumors

# %%
resize = 128
Dataset = []
Label = []
for i in range(0,len(dirYES)):
    if dirYES[i].split('.')[1] == 'jpg':
        image = Image.open(directory + 'yes/' + dirYES[i])
        image = image.resize((resize,resize)) #Reduce dimensionality
        Dataset.append(image)
        Label.append(1) # 1 For YES

# %% [markdown]
# #### Resize images without tumors

# %%
for i in range(0,len(dirNO)):
    if dirNO[i].split('.')[1] == 'jpg':
        image = Image.open(directory + 'no/' + dirNO[i])
        image = image.resize((resize,resize)) #Reduce dimensionality
        Dataset.append(image)
        Label.append(0) # 0 for NO

# %%
Dataset = np.array(Dataset)
Label = np.array(Label)
# Out:
# <ipython-input-35-7ecce2b7eafd>:1: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   Dataset = np.array(Dataset)
# <ipython-input-35-7ecce2b7eafd>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   Dataset = np.array(Dataset)

# %%
Dataset.shape, Label.shape
# Out:
# ((3000,), (3000,))

# %%
from matplotlib import pyplot as plt
plt.imshow(Dataset[0] , interpolation='nearest')
plt.show()

# %% [markdown]
# ### Split Data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(Dataset, Label, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (2400, 128, 128, 3)

# %%
y_train.shape
# Out:
# (2400,)

# %% [markdown]
# ## Convolutional Neural Network

# %% [markdown]
# ### Data Augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_generator = ImageDataGenerator(
    rescale = 1./255, #Normalization
    rotation_range = 90,
    shear_range = 0.2,
    zoom_range = 0.2,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    vertical_flip = True,
    horizontal_flip = True,
    fill_mode = 'nearest'
)

val_generator = ImageDataGenerator(rescale = 1./255)

train_iterator = train_generator.flow(X_train, y_train, batch_size = 32, shuffle = True)

val_iterator = val_generator.flow(X_test, y_test, batch_size = 32, shuffle = False)

# %% [markdown]
# ### Get pretrained model

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.python.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications.vgg16 import VGG16

# %%
# Create model
model = Sequential()
# Add pretrained model
model.add(VGG16(include_top = False, input_shape = (resize,resize,3) ,pooling = 'avg', weights = 'imagenet'))
# Add fully connected layer
model.add(Dense(16, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
# Out:
# ...
# 58892288/58889256 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# vgg16 (Functional)           (None, 512)               14714688
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                8208
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# ...
# Total params: 14,722,913
# Trainable params: 14,722,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'Adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Train the model

# %%
model.fit(train_iterator, epochs = 10, validation_data = val_iterator)
# Out:
# Epoch 1/10
# 23/24 [===========================>..] - ETA: 16s - loss: 5.8775e-08 - accuracy: 0.4961
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-c2a035993bf6> in <module>
# ----> 1 model.fit(train_iterator, epochs = 10, validation_data = val_iterator)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ...
